# %%
import pandas as pd

data = {
    "date": pd.date_range("2024-01-01", periods=100, freq="D"),
    "amount": [
        12000,3500,42000,8000,18000,9500,1500,27000,6000,52000,
        14000,4000,33000,7000,22000,11000,4500,28000,6500,48000,
        16000,3800,21000,5500,30000,9000,5000,36000,7200,15000,
        13000,4200,25000,6800,20000,17000,4800,31000,6000,45000,
        14000,3900,27000,7500,24000,15500,5200,34000,6300,12000,
        16500,4100,29000,7000,26000,14500,5300,38000,6800,20000,
        17500,4500,32000,7200,21000,13500,3900,26000,6500,18000,
        15000,4200,28000,7000,23000,16000,5000,35000,6000,22000,
        14000,3800,26000,6800,19000,15500,4700,30000,7200,21000,
        18000,4600,31000,7500,25000,14000,5100,32000,6900,23000
    ],
    "category": [
        "식비","교통비","쇼핑","카페","문화","식비","교통비","쇼핑","카페","의료"
    ] * 10,
    "description": [
        "점심","지하철","옷 구매","커피","영화","저녁","버스","생활용품","라떼","병원"
    ] * 10
}

df = pd.DataFrame(data)
df.to_csv("sample_data_100.csv", index=False, encoding="utf-8-sig")
